# %%
from IPython.display import YouTubeVideo
YouTubeVideo('5BAthiN0htc', width=600, height=400)

# %% [markdown]
# * [Dash Bio](https://dash.plot.ly/dash-bio)

# %% [markdown]
# * [mpld3](https://nbviewer.jupyter.org/url/jakevdp.github.com/downloads/notebooks/mpld3Demo.ipynb)
# * [folium](https://github.com/python-visualization/folium)

# %% [markdown]
# * [Bokeh](https://docs.bokeh.org/en/latest/)

# %% [markdown]
# * https://github.com/jupyter/dashboards/tree/master/etc/notebooks
# * https://github.com/plotly/dash
