# %% [markdown]
# # Github ReviewNB and ReviewBoard
# * https://blog.amirathi.com/2018/10/24/introducing-reviewnb-jupyter-notebook-visual-diff/
# * https://pypi.org/project/reviewboard-ipynb/

# %% [markdown]
# # nbdime: Jupyter Notebook Diff and Merge tools
# * https://github.com/jupyter/nbdime
# * https://nbdime.readthedocs.io/en/latest/

# %%
sudo -HE pip install nbdime
# Out:
# ...
#      |████████████████████████████████| 5.0MB 14.8MB/s eta 0:00:01
# ...

# %%
nbdime --help
# Out:
# Usage: nbdime [OPTIONS]
#
# OPTIONS: -h, --version, COMMANDS{show, diff, merge, diff-web, merge-web, mergetool, config-git, extensions}
#
# Examples: nbdime --version
#           nbdime show -h
#           nbdime merge-web
#
#           nbdime config-git (--enable | --disable)
#           nbdime extensions (--enable | --disable)
#
# Documentation: https://nbdime.readthedocs.io

# %% [markdown]
# ### https://nbdime.readthedocs.io/en/latest/cli.html
# * nbshow
# * nbdiff-web
# * nbmerge-web

# %%
cd ~/JHub/crypto-currency-stabilizer/\!-\!-secret-ico

# %%
nbdiff \!-\!-secret-ico-binance/\!-main.ipynb \!-main.ipynb
# Out:
# nbdiff !-!-secret-ico-binance/!-main.ipynb !-main.ipynb
# --- !-!-secret-ico-binance/!-main.ipynb  2021-03-08 02:00:47.967469
# +++ !-main.ipynb  2021-03-09 12:00:48.300356
# ## replaced (type changed from int to NoneType) /cells/1/execution_count:
# -  1
# +  None
#
# ## replaced (type changed from int to NoneType) /cells/2/execution_count:
# -  2
# +  None
#
# ## replaced (type changed from int to NoneType) /cells/4/execution_count:
# -  3
# +  None
#
# ## replaced /cells/6/execution_count:
# -  4
# +  9
#
# ## replaced (type changed from int to NoneType) /cells/8/execution_count:
# -  5
# +  None
#
# ## deleted /cells/8/outputs/0:
# -  output:
# -    output_type: stream
# -    name: stdout
# -    text:
# -      Requirement already satisfied: pyyaml in /home/jupyter-sheng_wei/.local/lib/python3.6/site-packages (5.1.2)
#
# ## replaced (type changed from int to NoneType) /cells/9/execution_count:
# -  6
# +  None
#
# ## modified /cells/9/source:
# ...

# %%
nbdiff-web \!-\!-secret-ico-binance/\!-main.ipynb \!-main.ipynb
# Out:
# [I nbdimeserver:423] Listening on 127.0.0.1, port 60774
# [I webutil:29] URL: http://127.0.0.1:60774/diff?base=%21-%21-secret-ico-binance%2F%21-main.ipynb&remote=%21-main.ipynb
# [I nbdimeserver:316] Closing server on remote request
