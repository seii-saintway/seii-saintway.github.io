# %%
from IPython.display import YouTubeVideo
YouTubeVideo('RQWpF2Gb-gU', width=600, height=400)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Dlsa9EBKDGI', width=600, height=400)

# %% [markdown]
# * https://github.com/keisukefujii/QulacsExamples/blob/master/GroverSearch.ipynb
# * https://github.com/keisukefujii/QulacsExamples/blob/master/5.2c1_application_of_QCL_to_classification.ipynb
# * https://github.com/awslabs/quantum-computing-exploration-for-drug-discovery-on-aws
